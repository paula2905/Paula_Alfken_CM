# %%
# 1: Rung Kutta method

def derivative(t, p_and_v):
    a = sin(t)
    v = p_and_v[1]
    return np.array([v,a])
def f(x):
    ode(derivative)

y = 1.
x = 0.
h = 0.5
for i in range(8):
    k1 = derivative(t, p_and_v)
    k2 = derivative(x+3/4*h)
    y = y + (1/3*k1+2/3*k2)*h
    print('approx.',y,'exact', f(x))
    x = x + h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-cd8587771c9c> in <module>
#      12 h = 0.5
#      13 for i in range(8):
# ---> 14     k1 = derivative(t, p_and_v)
#      15     k2 = derivative(x+3/4*h)
#      16     y = y + (1/3*k1+2/3*k2)*h
#
# NameError: name 't' is not defined

# %%
#2

def f(x):
    return -0.5*x**4+4*x**3-10*x**2+8.5*x+1
def der(x):
    return -2*x**3+12*x**2-20*x+8.5
approx_value=[]
x_value=[]
exact_value=[]

def euler(x0,x1,y1,s):
    while x0<x1:
        y1=y1+s*der(x0)
        x0=x0+s
        print("step:0.5--",x0,"approx:",y1,"exact:",f(x0))
        x_value.append(x0)
        exact_value.append(f(x0))
        approx_value.append(y1)
    
euler(0,4,0,0.5)
# Out:
# step:0.5-- 0.5 approx: 4.25 exact: 3.21875
# step:0.5-- 1.0 approx: 4.875 exact: 3.0
# step:0.5-- 1.5 approx: 4.125 exact: 2.21875
# step:0.5-- 2.0 approx: 3.5 exact: 2.0
# step:0.5-- 2.5 approx: 3.75 exact: 2.71875
# step:0.5-- 3.0 approx: 4.875 exact: 4.0
# step:0.5-- 3.5 approx: 6.125 exact: 4.71875
# step:0.5-- 4.0 approx: 6.0 exact: 3.0

# %%
#3- Study the effect of changing the step size in Euler methods by plotting the approximated vs. exact solutions at different values of h (0.5, 0.25, 0.025) for the example in slide 4 in lecture 5.
import matplotlib.pyplot as plt
def f(x):
    return -0.5*x**4+4*x**3-10*x**2+8.5*x+1
def der(x):
    return -2*x**3+12*x**2-20*x+8.5
approx_value=[]
x_value=[]
exact_value=[]
def euler(x0,x1,y1,s):
    while x0<x1:
        y1=y1+s*der(x0)
        x0=x0+s
        print("step:0.5--",x0,"approx:",y1,"exact:",f(x0))
        x_value.append(x0)
        exact_value.append(f(x0))
        approx_value.append(y1)
x0=0
x1=4
y1=0
s=0.5
euler(x0,x1,y1,s)

approx_value1=[]
x_value1=[]
exact_value1=[]
def euler(x0,x1,y1,s):
    while x0<x1:
        y1=y1+s*der(x0)
        x0=x0+s
        print("step:0.25--",x0,"approx:",y1,"exact:",f(x0))
        x_value1.append(x0)
        exact_value1.append(f(x0))
        approx_value1.append(y1)  
x0=0
x1=4
y1=0
s=0.25        
euler(x0,x1,y1,s)

approx_value2=[]
x_value2=[]
exact_value2=[]
def euler(x0,x1,y1,s):
    while x0<x1:
        y1=y1+s*der(x0)
        x0=x0+s
        print("step:0.025--",x0,"approx:",y1,"exact:",f(x0))
        x_value2.append(x0)
        exact_value2.append(f(x0))
        approx_value2.append(y1)
x0=0
x1=4
y1=0
s=0.025
euler(x0,x1,y1,s)

# %matplotlib inline
fig, ax = plt.subplots(3)
ax[0].plot(x_value,approx_value,x_value,exact_value)
ax[1].plot(x_value1,approx_value1,x_value1,exact_value1)
ax[2].plot(x_value2,approx_value2,x_value2,exact_value2)
plt.show()
# Out:
# step:0.5-- 0.5 approx: 4.25 exact: 3.21875
# step:0.5-- 1.0 approx: 4.875 exact: 3.0
# step:0.5-- 1.5 approx: 4.125 exact: 2.21875
# step:0.5-- 2.0 approx: 3.5 exact: 2.0
# step:0.5-- 2.5 approx: 3.75 exact: 2.71875
# step:0.5-- 3.0 approx: 4.875 exact: 4.0
# step:0.5-- 3.5 approx: 6.125 exact: 4.71875
# step:0.5-- 4.0 approx: 6.0 exact: 3.0
# step:0.25-- 0.25 approx: 2.125 exact: 2.560546875
# step:0.25-- 0.5 approx: 3.1796875 exact: 3.21875
# step:0.25-- 0.75 approx: 3.4921875 exact: 3.279296875
# step:0.25-- 1.0 approx: 3.34375 exact: 3.0
# step:0.25-- 1.25 approx: 2.96875 exact: 2.591796875
# step:0.25-- 1.5 approx: 2.5546875 exact: 2.21875
# step:0.25-- 1.75 approx: 2.2421875 exact: 1.998046875
# step:0.25-- 2.0 approx: 2.125 exact: 2.0
# step:0.25-- 2.25 approx: 2.25 exact: 2.248046875
# step:0.25-- 2.5 approx: 2.6171875 exact: 2.71875
# step:0.25-- 2.75 approx: 3.1796875 exact: 3.341796875
# step:0.25-- 3.0 approx: 3.84375 exact: 4.0
# step:0.25-- 3.25 approx: 4.46875 exact: 4.529296875
# step:0.25-- 3.5 approx: 4.8671875 exact: 4.71875
# step:0.25-- 3.75 approx: 4.8046875 exact: 4.310546875
# step:0.25-- 4.0 approx: 4.0 exact: 3.0
# step:0.025-- 0.025 approx: 0.21250000000000002 exact: 1.2063123046875
# step:0.025-- 0.05 approx: 0.41268671875 exact: 1.400496875
# step:0.025-- 0.07500000000000001 approx: 0.60093046875 exact: 1.5829216796875
# step:0.025-- 0.1 approx: 0.777596875 exact: 1.7539500000000001
# step:0.025-- 0.125 approx: 0.943046875 exact: 1.9139404296875
# step:0.025-- 0.15 approx: 1.09763671875 exact: 2.063246875
# step:0.025-- 0.175 approx: 1.24171796875 exact: 2.2022185546874997
# step:0.025-- 0.19999999999999998 approx: 1.3756374999999998 exact: 2.3312
# step:0.025-- 0.22499999999999998 approx: 1.4997375 exact: 2.4505310546875
# step:0.025-- 0.24999999999999997 approx: 1.61435546875 exact: 2.5605468749999996
# step:0.025-- 0.27499999999999997 approx: 1.71982421875 exact: 2.6615779296874997
# step:0.025-- 0.3 approx: 1.816471875 exact: 2.7539499999999997
# step:0.025-- 0.325 approx: 1.904621875 exact: 2.8379841796875
# step:0.025-- 0.35000000000000003 approx: 1.98459296875 exact: 2.9139968749999996
# step:0.025-- 0.37500000000000006 approx: 2.05669921875 exact: 2.9822998046875
# step:0.025-- 0.4000000000000001 approx: 2.12125 exact: 3.0432000000000006
# step:0.025-- 0.4250000000000001 approx: 2.17855 exact: 3.0969998046875
# step:0.025-- 0.4500000000000001 approx: 2.22889921875 exact: 3.1439968750000005
# step:0.025-- 0.47500000000000014 approx: 2.27259296875 exact: 3.1844841796875003
# step:0.025-- 0.5000000000000001 approx: 2.309921875 exact: 3.2187500000000004
# step:0.025-- 0.5250000000000001 approx: 2.341171875 exact: 3.2470779296875003
# step:0.025-- 0.5500000000000002 approx: 2.36662421875 exact: 3.2697468750000005
# step:0.025-- 0.5750000000000002 approx: 2.38655546875 exact: 3.2870310546874997
# step:0.025-- 0.6000000000000002 approx: 2.4012375 exact: 3.2991999999999995
# step:0.025-- 0.6250000000000002 approx: 2.4109375 exact: 3.3065185546875
# step:0.025-- 0.6500000000000002 approx: 2.41591796875 exact: 3.309246875
# step:0.025-- 0.6750000000000003 approx: 2.41643671875 exact: 3.307640429687501
# step:0.025-- 0.7000000000000003 approx: 2.412746875 exact: 3.3019500000000006
# step:0.025-- 0.7250000000000003 approx: 2.405096875 exact: 3.292421679687499
# step:0.025-- 0.7500000000000003 approx: 2.39373046875 exact: 3.279296874999999
# step:0.025-- 0.7750000000000004 approx: 2.37888671875 exact: 3.2628123046875004
# step:0.025-- 0.8000000000000004 approx: 2.3608 exact: 3.2432
# step:0.025-- 0.8250000000000004 approx: 2.3396999999999997 exact: 3.220687304687499
# step:0.025-- 0.8500000000000004 approx: 2.3158117187499996 exact: 3.195496875
# step:0.025-- 0.8750000000000004 approx: 2.2893554687499997 exact: 3.167846679687499
# step:0.025-- 0.9000000000000005 approx: 2.2605468749999997 exact: 3.137949999999999
# step:0.025-- 0.9250000000000005 approx: 2.2295968749999995 exact: 3.106015429687499
# step:0.025-- 0.9500000000000005 approx: 2.1967117187499996 exact: 3.0722468749999994
# step:0.025-- 0.9750000000000005 approx: 2.1620929687499997 exact: 3.0368435546874997
# step:0.025-- 1.0000000000000004 approx: 2.1259374999999996 exact: 2.999999999999999
# step:0.025-- 1.0250000000000004 approx: 2.0884374999999995 exact: 2.961906054687498
# step:0.025-- 1.0500000000000003 approx: 2.0497804687499994 exact: 2.9227468749999996
# step:0.025-- 1.0750000000000002 approx: 2.010149218749999 exact: 2.8827029296874986
# step:0.025-- 1.1 approx: 1.9697218749999992 exact: 2.8419500000000015
# step:0.025-- 1.125 approx: 1.9286718749999991 exact: 2.8006591796875
# step:0.025-- 1.15 approx: 1.8871679687499991 exact: 2.758996875000001
# step:0.025-- 1.1749999999999998 approx: 1.845374218749999 exact: 2.7171248046875025
# step:0.025-- 1.1999999999999997 approx: 1.803449999999999 exact: 2.6752000000000002
# step:0.025-- 1.2249999999999996 approx: 1.761549999999999 exact: 2.6333748046875005
# step:0.025-- 1.2499999999999996 approx: 1.719824218749999 exact: 2.591796875
# step:0.025-- 1.2749999999999995 approx: 1.678417968749999 exact: 2.5506091796875
# step:0.025-- 1.2999999999999994 approx: 1.6374718749999988 exact: 2.5099500000000017
# step:0.025-- 1.3249999999999993 approx: 1.5971218749999987 exact: 2.4699529296875014
# step:0.025-- 1.3499999999999992 approx: 1.5574992187499987 exact: 2.4307468750000023
# step:0.025-- 1.3749999999999991 approx: 1.5187304687499987 exact: 2.3924560546875036
# step:0.025-- 1.399999999999999 approx: 1.4809374999999987 exact: 2.3552000000000017
# step:0.025-- 1.424999999999999 approx: 1.4442374999999987 exact: 2.3190935546875
# step:0.025-- 1.4499999999999988 approx: 1.4087429687499988 exact: 2.2842468750000062
# step:0.025-- 1.4749999999999988 approx: 1.3745617187499988 exact: 2.250765429687503
# step:0.025-- 1.4999999999999987 approx: 1.3417968749999987 exact: 2.2187500000000018
# step:0.025-- 1.5249999999999986 approx: 1.3105468749999987 exact: 2.188296679687504
# step:0.025-- 1.5499999999999985 approx: 1.2809054687499986 exact: 2.1594968749999985
# step:0.025-- 1.5749999999999984 approx: 1.2529617187499984 exact: 2.1324373046875014
# step:0.025-- 1.5999999999999983 approx: 1.2267999999999983 exact: 2.107199999999997
# step:0.025-- 1.6249999999999982 approx: 1.2024999999999983 exact: 2.0838623046875
# step:0.025-- 1.6499999999999981 approx: 1.1801367187499983 exact: 2.0624968750000026
# step:0.025-- 1.674999999999998 approx: 1.1597804687499982 exact: 2.043171679687502
# step:0.025-- 1.699999999999998 approx: 1.141496874999998 exact: 2.0259500000000035
# step:0.025-- 1.7249999999999979 approx: 1.125346874999998 exact: 2.0108904296874943
# step:0.025-- 1.7499999999999978 approx: 1.1113867187499977 exact: 1.9980468750000018
# step:0.025-- 1.7749999999999977 approx: 1.0996679687499973 exact: 1.9874685546875028
# step:0.025-- 1.7999999999999976 approx: 1.090237499999997 exact: 1.9792000000000023
# step:0.025-- 1.8249999999999975 approx: 1.083137499999997 exact: 1.9732810546874937
# step:0.025-- 1.8499999999999974 approx: 1.0784054687499969 exact: 1.9697468749999967
# step:0.025-- 1.8749999999999973 approx: 1.0760742187499965 exact: 1.9686279296874982
# step:0.025-- 1.8999999999999972 approx: 1.0761718749999964 exact: 1.9699499999999972
# step:0.025-- 1.9249999999999972 approx: 1.0787218749999963 exact: 1.9737341796874972
# step:0.025-- 1.949999999999997 approx: 1.083742968749996 exact: 1.9799968749999977
# step:0.025-- 1.974999999999997 approx: 1.0912492187499958 exact: 1.9887498046874938
# step:0.025-- 1.999999999999997 approx: 1.1012499999999956 exact: 2.0000000000000036
# step:0.025-- 2.024999999999997 approx: 1.1137499999999954 exact: 2.0137498046875066
# step:0.025-- 2.0499999999999967 approx: 1.1287492187499948 exact: 2.0299968749999984
# step:0.025-- 2.0749999999999966 approx: 1.1462429687499944 exact: 2.0487341796875
# step:0.025-- 2.0999999999999965 approx: 1.1662218749999944 exact: 2.069950000000002
# step:0.025-- 2.1249999999999964 approx: 1.188671874999994 exact: 2.0936279296874964
# step:0.025-- 2.1499999999999964 approx: 1.2135742187499936 exact: 2.1197468749999935
# step:0.025-- 2.1749999999999963 approx: 1.2409054687499932 exact: 2.1482810546875015
# step:0.025-- 2.199999999999996 approx: 1.2706374999999928 exact: 2.1792000000000016
# step:0.025-- 2.224999999999996 approx: 1.3027374999999923 exact: 2.212468554687497
# step:0.025-- 2.249999999999996 approx: 1.337167968749992 exact: 2.248046874999993
# step:0.025-- 2.274999999999996 approx: 1.3738867187499917 exact: 2.2858904296874947
# step:0.025-- 2.299999999999996 approx: 1.4128468749999914 exact: 2.3259499999999953
# step:0.025-- 2.3249999999999957 approx: 1.453996874999991 exact: 2.3681716796874888
# step:0.025-- 2.3499999999999956 approx: 1.4972804687499908 exact: 2.4124968749999915
# step:0.025-- 2.3749999999999956 approx: 1.5426367187499905 exact: 2.4588623046874964
# step:0.025-- 2.3999999999999955 approx: 1.58999999999999 exact: 2.5071999999999974
# step:0.025-- 2.4249999999999954 approx: 1.6392999999999902 exact: 2.5574373046874896
# step:0.025-- 2.4499999999999953 approx: 1.6904617187499902 exact: 2.6094968749999836
# step:0.025-- 2.474999999999995 approx: 1.74340546874999 exact: 2.663296679687484
# step:0.025-- 2.499999999999995 approx: 1.7980468749999896 exact: 2.718749999999986
# step:0.025-- 2.524999999999995 approx: 1.8542968749999895 exact: 2.775765429687496
# step:0.025-- 2.549999999999995 approx: 1.912061718749989 exact: 2.8342468749999945
# step:0.025-- 2.574999999999995 approx: 1.9712429687499886 exact: 2.8940935546874904
# step:0.025-- 2.5999999999999948 approx: 2.031737499999988 exact: 2.95519999999998
# step:0.025-- 2.6249999999999947 approx: 2.0934374999999883 exact: 3.0174560546874893
# step:0.025-- 2.6499999999999946 approx: 2.156230468749988 exact: 3.080746874999992
# step:0.025-- 2.6749999999999945 approx: 2.2199992187499875 exact: 3.144952929687477
# step:0.025-- 2.6999999999999944 approx: 2.284621874999987 exact: 3.209949999999999
# step:0.025-- 2.7249999999999943 approx: 2.3499718749999867 exact: 3.2756091796874784
# step:0.025-- 2.7499999999999942 approx: 2.4159179687499868 exact: 3.3417968749999787
# step:0.025-- 2.774999999999994 approx: 2.4823242187499868 exact: 3.408374804687483
# step:0.025-- 2.799999999999994 approx: 2.5490499999999865 exact: 3.475199999999983
# step:0.025-- 2.824999999999994 approx: 2.6159499999999865 exact: 3.542124804687486
# step:0.025-- 2.849999999999994 approx: 2.682874218749986 exact: 3.608996874999985
# step:0.025-- 2.874999999999994 approx: 2.7496679687499856 exact: 3.6756591796874893
# step:0.025-- 2.8999999999999937 approx: 2.816171874999986 exact: 3.741949999999985
# step:0.025-- 2.9249999999999936 approx: 2.882221874999986 exact: 3.807702929687494
# step:0.025-- 2.9499999999999935 approx: 2.947649218749986 exact: 3.8727468750000043
# step:0.025-- 2.9749999999999934 approx: 3.012280468749986 exact: 3.936906054687462
# step:0.025-- 2.9999999999999933 approx: 3.0759374999999864 exact: 3.9999999999999716
# step:0.025-- 3.0249999999999932 approx: 3.1384374999999873 exact: 4.061843554687478
# step:0.025-- 3.049999999999993 approx: 3.1995929687499878 exact: 4.122246874999988
# step:0.025-- 3.074999999999993 approx: 3.259211718749988 exact: 4.181015429687502
# step:0.025-- 3.099999999999993 approx: 3.3170968749999887 exact: 4.237949999999987
# step:0.025-- 3.124999999999993 approx: 3.3730468749999893 exact: 4.292846679687482
# step:0.025-- 3.149999999999993 approx: 3.4268554687499897 exact: 4.345496874999984
# step:0.025-- 3.1749999999999927 approx: 3.4783117187499903 exact: 4.395687304687467
# step:0.025-- 3.1999999999999926 approx: 3.527199999999991 exact: 4.443199999999997
# step:0.025-- 3.2249999999999925 approx: 3.5732999999999917 exact: 4.487812304687509
# step:0.025-- 3.2499999999999925 approx: 3.6163867187499923 exact: 4.529296874999979
# step:0.025-- 3.2749999999999924 approx: 3.6562304687499934 exact: 4.567421679687499
# step:0.025-- 3.2999999999999923 approx: 3.6925968749999942 exact: 4.601949999999995
# step:0.025-- 3.324999999999992 approx: 3.7252468749999954 exact: 4.632640429687484
# step:0.025-- 3.349999999999992 approx: 3.7539367187499963 exact: 4.65924687499999
# step:0.025-- 3.374999999999992 approx: 3.7784179687499977 exact: 4.6815185546875036
# step:0.025-- 3.399999999999992 approx: 3.7984374999999995 exact: 4.699199999999987
# step:0.025-- 3.424999999999992 approx: 3.813737500000001 exact: 4.7120310546874755
# step:0.025-- 3.4499999999999917 approx: 3.8240554687500032 exact: 4.719746874999981
# step:0.025-- 3.4749999999999917 approx: 3.829124218750005 exact: 4.722077929687494
# step:0.025-- 3.4999999999999916 approx: 3.8286718750000066 exact: 4.718749999999986
# step:0.025-- 3.5249999999999915 approx: 3.8224218750000087 exact: 4.7094841796875
# step:0.025-- 3.5499999999999914 approx: 3.810092968750011 exact: 4.6939968750000105
# step:0.025-- 3.5749999999999913 approx: 3.7913992187500134 exact: 4.671999804687495
# step:0.025-- 3.599999999999991 approx: 3.7660500000000163 exact: 4.643200000000011
# step:0.025-- 3.624999999999991 approx: 3.7337500000000188 exact: 4.607299804687511
# step:0.025-- 3.649999999999991 approx: 3.6941992187500214 exact: 4.563996875000033
# step:0.025-- 3.674999999999991 approx: 3.647092968750024 exact: 4.512984179687532
# step:0.025-- 3.699999999999991 approx: 3.5921218750000268 exact: 4.45395000000001
# step:0.025-- 3.7249999999999908 approx: 3.5289718750000296 exact: 4.386577929687533
# step:0.025-- 3.7499999999999907 approx: 3.4573242187500335 exact: 4.310546875000021
# step:0.025-- 3.7749999999999906 approx: 3.376855468750037 exact: 4.225531054687536
# step:0.025-- 3.7999999999999905 approx: 3.2872375000000402 exact: 4.131200000000014
# step:0.025-- 3.8249999999999904 approx: 3.1881375000000443 exact: 4.027218554687536
# step:0.025-- 3.8499999999999903 approx: 3.079217968750049 exact: 3.913246875000034
# step:0.025-- 3.8749999999999902 approx: 2.9601367187500527 exact: 3.788940429687557
# step:0.025-- 3.89999999999999 approx: 2.830546875000057 exact: 3.6539500000000444
# step:0.025-- 3.92499999999999 approx: 2.6900968750000613 exact: 3.507921679687527
# step:0.025-- 3.94999999999999 approx: 2.5384304687500663 exact: 3.3504968750000614
# step:0.025-- 3.97499999999999 approx: 2.3751867187500713 exact: 3.181312304687559
# step:0.025-- 3.99999999999999 approx: 2.2000000000000766 exact: 3.0000000000000853
# step:0.025-- 4.02499999999999 approx: 2.012500000000082 exact: 2.8061873046875903
